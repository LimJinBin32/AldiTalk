# %%
"""[Adjusted] Sample Code from AWS"""
"""This code takes in a root directory folder with images/frames inside and applies OCR to extract text from them with matching frame number."""

from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from msrest.authentication import CognitiveServicesCredentials

import os
import time
import json

# Authentication
subscription_key = os.environ["AI_SERVICES_KEY"]
endpoint = os.environ["AI_SERVICES_ENDPOINT"]

# Start the client server
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

# Main folder containing subfolders of images
main_folder = "frames" # YOUR FOLDER PATH HERE

def process_image(image_path):
    # Change local path to a URL
    with open(image_path, "rb") as image_stream:
        # Call the OCR Read API
        read_response = computervision_client.read_in_stream(image_stream, raw=True)

    # Get the operation location (URL with an ID at the end) from the response
    read_operation_location = read_response.headers["Operation-Location"]
    # Grab the ID from the URL
    operation_id = read_operation_location.split("/")[-1]

    # Call the "GET" API and wait for it to retrieve the results 
    while True:
        read_result = computervision_client.get_read_result(operation_id)
        if read_result.status not in ['notStarted', 'running']:
            break
        time.sleep(1)
                
    # Extract and return the text
    if read_result.status == OperationStatusCodes.succeeded:
        text_lines = []
        for page in read_result.analyze_result.read_results:
            for line in page.lines:
                text_lines.append(line.text)
        return text_lines
    else:
        return None

# Traverse the main folder and its subfolders
for root, dirs, files in os.walk(main_folder):
    # Collect image paths in the current subfolder
    image_paths = [os.path.join(root, file) for file in files if file.endswith((".jpg", ".png", ".jpeg"))]
    
    if not image_paths:
        continue  # Skip if no images in the folder

    # Dictionary to store OCR results and status
    results = {}
    status = {}

    # Process all images in the current subfolder
    for image_path in image_paths:
        print(f"Processing image: {image_path}")
        text = process_image(image_path)
        image_name = os.path.basename(image_path)  # Extract the file name
        if text:
            results[image_name] = text
            status[image_name] = True
        else:
            status[image_name] = False
            print(f"Failed to process image: {image_path}")

    # Save results for the current subfolder
    folder_name = os.path.basename(root)
    output_folder = os.path.join("ocr", folder_name)
    os.makedirs(output_folder, exist_ok=True)

    # Save results to JSON files
    result_file = os.path.join(output_folder, "ocr_results.json")
    status_file = os.path.join(output_folder, "status.json")
    
    with open(result_file, "w", encoding="utf-8") as f:
        json.dump(results, f, indent=4, ensure_ascii=False)

    with open(status_file, "w", encoding="utf-8") as f:
        json.dump(status, f, indent=4, ensure_ascii=False)

    print(f"Results for folder '{folder_name}' saved to {output_folder}")
# Out:
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_360.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_570.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_210.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_600.jpg
# Failed to process image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_600.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_510.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_300.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_270.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_450.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_240.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_480.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_330.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_180.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_540.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_420.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_150.jpg
# Failed to process image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_150.jpg
# Processing image: frames/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv/frame_390.jpg
# Results for folder '天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv' saved to ocr/天之驕女│最新台語八點檔大戲即將上映！天之蕉子續集 Proud of You│ Vidol.tv
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1530.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_360.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_360.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1860.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1860.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_570.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1080.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1080.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1650.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1320.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1320.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_990.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1680.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_60.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1290.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1290.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_600.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1050.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1050.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1440.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1440.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_510.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1590.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_840.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1140.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1140.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1020.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_300.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_300.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1800.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1380.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_270.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_270.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_660.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_660.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_930.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1350.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1350.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1620.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1740.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1230.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_900.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1770.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_690.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1200.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_120.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_450.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_240.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_240.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1410.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1170.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_480.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1560.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_330.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1830.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_720.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_870.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_750.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1920.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1920.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_630.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_180.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1470.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1470.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_960.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_90.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1710.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1260.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_540.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_420.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_150.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_810.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_390.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1890.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1890.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_780.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1110.jpg
# Failed to process image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1110.jpg
# Processing image: frames/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama/frame_1500.jpg
# Results for folder 'Shielding Your Future Care Needs: Ep 2- Taiwanese Drama' saved to ocr/Shielding Your Future Care Needs: Ep 2- Taiwanese Drama
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_360.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_570.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_570.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_210.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_60.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_600.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_600.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_510.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_270.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_450.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_240.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_480.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_330.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_630.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_630.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_180.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_90.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_540.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_420.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_150.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告/frame_390.jpg
# Results for folder '“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告' saved to ocr/“I Want To Be A Towkay” Episode 2 Trailer《亲家，冤家做头家》第二集预告
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_360.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_570.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_210.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_60.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_600.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_510.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_840.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_300.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_270.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_660.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_900.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_690.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_120.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_450.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_240.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_480.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_330.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_720.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_870.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_750.jpg
# Failed to process image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_750.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_630.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_180.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_90.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_540.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_420.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_150.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_810.jpg
# Failed to process image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_810.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_390.jpg
# Processing image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_780.jpg
# Failed to process image: frames/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道/frame_780.jpg
# Results for folder '下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道' saved to ocr/下週一預告搶先看｜靜玉真的愛文堯 吃醋告狀長勝！長勝誓要完成靜玉願望！｜天道
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_360.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_360.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_570.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_570.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_990.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_210.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_210.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_60.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_600.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_600.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_510.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_510.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_840.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_1020.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_1020.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_300.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_300.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_270.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_270.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_660.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_660.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_930.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_900.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_690.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_690.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_120.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_120.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_450.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_450.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_240.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_480.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_480.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_330.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_330.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_720.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_720.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_870.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_750.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_750.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_630.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_630.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_180.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_180.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_960.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_90.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_90.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_420.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_420.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_150.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_150.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_810.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_390.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_390.jpg
# Processing image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_780.jpg
# Failed to process image: frames/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告/frame_780.jpg
# Results for folder '“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告' saved to ocr/“I Want To Be A Towkay” Episode 1 Trailer《亲家，冤家做头家》第一集预告
